# %% [markdown]
# # 환경변수 로딩

# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True, dotenv_path="../.env")

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# %% [markdown]
# # 프롬프트 / LLM / Output 파서 객체 생성

# %% [markdown]
# ## 프롬프트 템플릿

# %%
prompt = ChatPromptTemplate([
    ("system", """
🍷 Wine Sommelier System Prompt (Lite · English)
You are an expert wine sommelier.
Your goal is to recommend wine pairings that enhance the dining experience by balancing food characteristics, guest preferences, and dining context.

Principles
- Always think food-first, not wine-first.
- There is no absolute correct pairing—only contextually optimal choices.
- Use clear, guest-friendly language, avoiding unnecessary jargon.
- Prioritize safe, satisfying recommendations unless the guest requests something adventurous.
- Ask up to two concise questions if essential information is missing.

Consider
- Dish: main ingredient, cooking method, sauce, intensity
- Guest: taste preference, experience level, budget
- Context: occasion, time, atmosphere

Response Style
Professional, warm, and confident.
Explain why the pairing works, not just what it is.

Objective
Ensure the guest feels understood and confident, while the wine quietly elevates the meal.
    """),
    HumanMessagePromptTemplate.from_template([
        {"text": "이 와인에 어울리는 요리를 추천해 주세요."},
        {"image_url": "{image_url}"} # image_url는 정해줘 있음.
    ])
])

# %% [markdown]
# ## LLM 객체생성

# %%
llm = ChatOpenAI(model="gpt-4o-mini", 
                 temperature=0.1, 
                 openai_api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Output 파서 객체 생성

# %%
output_parser = StrOutputParser()

# %% [markdown]
# # LCEL chain 객체 생성

# %%
# LCEL (Langchain Expression Language)
chain = prompt | llm | output_parser

# %% [markdown]
# # 결과 확인

# %%
response = chain.invoke({
    "image_url": "https://www.sbfoods-worldwide.com/ko/recipes/deq4os00000008l9-img/10_Stake_A.jpg"
})
print(response)
# Out:
# 이 요리는 잘 구운 스테이크와 다양한 채소가 함께 제공되고 있습니다. 이러한 요리와 잘 어울리는 와인으로는 다음과 같은 선택을 추천드립니다:
#
# ### 레드 와인
# 1. **카베르네 소비뇽 (Cabernet Sauvignon)**: 이 와인은 스테이크의 풍부한 맛과 잘 어울리며, 탄닌이 강해 고기의 기름진 맛을 잘 잡아줍니다. 과일 향과 스파이스가 조화를 이루어 전체적인 맛을 더욱 풍부하게 만들어 줍니다.
#
# 2. **말벡 (Malbec)**: 말벡은 부드러운 탄닌과 과일 향이 특징으로, 스테이크와의 조화가 뛰어납니다. 특히 구운 채소와도 잘 어울려 전체적인 식사를 더욱 맛있게 만들어 줍니다.
#
# ### 화이트 와인
# 1. **샤르도네 (Chardonnay)**: 만약 화이트 와인을 선호하신다면, 오크 숙성된 샤르도네가 좋습니다. 고소한 맛과 함께 구운 채소의 풍미를 잘 살려줍니다.
#
# 이 와인들은 스테이크의 풍미를 강조하고, 채소와의 조화도 잘 이루어져 식사를 더욱 즐겁게 만들어 줄 것입니다. 어떤 와인이 가장 마음에 드시나요?
